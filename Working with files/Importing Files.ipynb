# %% [markdown]
# ### Importing CSV Files

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.csv')
df
# Out:
#     employee_id    first_name     last_name   age  gender  birth_date
# 0             1        Leslie         Knope  44.0  Female   9/25/1979
# 1             3           Tom     Haverford  36.0    Male    3/4/1987
# 2             4         April       Ludgate  29.0  Female   3/27/1994
# 3             6         Donna        Meagle  46.0  Female   7/30/1977
# 4             7           Ann       Perkins  35.0  Female   12/1/1988
# 5             8         Chris       Traeger  43.0    Male  11/11/1980
# 6             9           Ben         Wyatt  38.0    Male   7/26/1985
# 7            10          Andy         Dwyer  34.0    Male   3/25/1989
# 8            11          Mark  Brendanawicz  40.0    Male   6/14/1983
# 9            12         Craig  Middlebrooks  37.0    Male   7/27/1986
# 10           13  Jean-Ralphio    Saperstein   NaN     NaN         NaN

# %%
df = pd.read_csv(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.tsv',
                sep = "\t")
df
# Out:
#     employee_id    first_name     last_name   age  gender  birth_date
# 0             1        Leslie         Knope  44.0  Female   9/25/1979
# 1             3           Tom     Haverford  36.0    Male    3/4/1987
# 2             4         April       Ludgate  29.0  Female   3/27/1994
# 3             6         Donna        Meagle  46.0  Female   7/30/1977
# 4             7           Ann       Perkins  35.0  Female   12/1/1988
# 5             8         Chris       Traeger  43.0    Male  11/11/1980
# 6             9           Ben         Wyatt  38.0    Male   7/26/1985
# 7            10          Andy         Dwyer  34.0    Male   3/25/1989
# 8            11          Mark  Brendanawicz  40.0    Male   6/14/1983
# 9            12         Craig  Middlebrooks  37.0    Male   7/27/1986
# 10           13  Jean-Ralphio    Saperstein   NaN     NaN         NaN

# %%
df = pd.read_csv(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.csv'
                ,usecols = ['first_name','last_name'])
df
# Out:
#       first_name     last_name
# 0         Leslie         Knope
# 1            Tom     Haverford
# 2          April       Ludgate
# 3          Donna        Meagle
# 4            Ann       Perkins
# 5          Chris       Traeger
# 6            Ben         Wyatt
# 7           Andy         Dwyer
# 8           Mark  Brendanawicz
# 9          Craig  Middlebrooks
# 10  Jean-Ralphio    Saperstein

# %%
#Reading Strange Data
df = pd.read_csv('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation_strange_data.csv'
                ,skiprows = [0,1,2], names = ['employee_id','first_name','last_name','age','gender','birth_date'])

df
# Out:
#     employee_id    first_name     last_name   age  gender  birth_date
# 0             1        Leslie         Knope  44.0  Female   9/25/1979
# 1             3           Tom     Haverford  36.0    Male    3/4/1987
# 2             4         April       Ludgate  29.0  Female   3/27/1994
# 3             6         Donna        Meagle  46.0  Female   7/30/1977
# 4             7           Ann       Perkins  35.0  Female   12/1/1988
# 5             8         Chris       Traeger  43.0    Male  11/11/1980
# 6             9           Ben         Wyatt  38.0    Male   7/26/1985
# 7            10          Andy         Dwyer  34.0    Male   3/25/1989
# 8            11          Mark  Brendanawicz  40.0    Male   6/14/1983
# 9            12         Craig  Middlebrooks  37.0    Male   7/27/1986
# 10           13  Jean-Ralphio    Saperstein   NaN     NaN         NaN

# %% [markdown]
# ### IMPORTING Different File Types (JSON,Text,Excel)

# %%
#Reading JSON

df = pd.read_json('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.json')

df
# Out:
#     employee_id    first_name     last_name   age  gender  birth_date
# 0             1        Leslie         Knope  44.0  Female   9/25/1979
# 1             3           Tom     Haverford  36.0    Male    3/4/1987
# 2             4         April       Ludgate  29.0  Female   3/27/1994
# 3             6         Donna        Meagle  46.0  Female   7/30/1977
# 4             7           Ann       Perkins  35.0  Female   12/1/1988
# 5             8         Chris       Traeger  43.0    Male  11/11/1980
# 6             9           Ben         Wyatt  38.0    Male   7/26/1985
# 7            10          Andy         Dwyer  34.0    Male   3/25/1989
# 8            11          Mark  Brendanawicz  40.0    Male   6/14/1983
# 9            12         Craig  Middlebrooks  37.0    Male   7/27/1986
# 10           13  Jean-Ralphio    Saperstein   NaN    None        None

# %%
#Reading txt

df = pd.read_table('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.txt')

df
# Out:
#     employee_id    first_name     last_name   age  gender  birth_date
# 0             1        Leslie         Knope  44.0  Female   9/25/1979
# 1             3           Tom     Haverford  36.0    Male    3/4/1987
# 2             4         April       Ludgate  29.0  Female   3/27/1994
# 3             6         Donna        Meagle  46.0  Female   7/30/1977
# 4             7           Ann       Perkins  35.0  Female   12/1/1988
# 5             8         Chris       Traeger  43.0    Male  11/11/1980
# 6             9           Ben         Wyatt  38.0    Male   7/26/1985
# 7            10          Andy         Dwyer  34.0    Male   3/25/1989
# 8            11          Mark  Brendanawicz  40.0    Male   6/14/1983
# 9            12         Craig  Middlebrooks  37.0    Male   7/27/1986
# 10           13  Jean-Ralphio    Saperstein   NaN     NaN         NaN

# %%
#Read Excel

df = pd.read_excel('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.xlsx',
                  sheet_name = 'demographics')

df
# Out:
#     employee_id    first_name     last_name   age  gender birth_date
# 0             1        Leslie         Knope  44.0  Female 1979-09-25
# 1             3           Tom     Haverford  36.0    Male 1987-03-04
# 2             4         April       Ludgate  29.0  Female 1994-03-27
# 3             6         Donna        Meagle  46.0  Female 1977-07-30
# 4             7           Ann       Perkins  35.0  Female 1988-12-01
# 5             8         Chris       Traeger  43.0    Male 1980-11-11
# 6             9           Ben         Wyatt  38.0    Male 1985-07-26
# 7            10          Andy         Dwyer  34.0    Male 1989-03-25
# 8            11          Mark  Brendanawicz  40.0    Male 1983-06-14
# 9            12         Craig  Middlebrooks  37.0    Male 1986-07-27
# 10           13  Jean-Ralphio    Saperstein   NaN     NaN        NaT
