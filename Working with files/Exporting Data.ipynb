# %% [markdown]
# ## Exporting Data

# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/parks_and_recreation.csv')

df
# Out:
#     Unnamed: 0  employee_id    first_name     last_name   age  gender  \
# 0            0            1        Leslie         Knope  44.0  Female
# 1            1            3           Tom     Haverford  36.0    Male
# 2            2            4         April       Ludgate  29.0  Female
# 3            3            6         Donna        Meagle  46.0  Female
# 4            4            7           Ann       Perkins  35.0  Female
# 5            5            8         Chris       Traeger  43.0    Male
# 6            6            9           Ben         Wyatt  38.0    Male
# 7            7           10          Andy         Dwyer  34.0    Male
# 8            8           11          Mark  Brendanawicz  40.0    Male
# 9            9           12         Craig  Middlebrooks  37.0    Male
# 10          10           13  Jean-Ralphio    Saperstein   NaN     NaN
#
#     birth_date
# 0    9/25/1979
# 1     3/4/1987
# 2    3/27/1994
# 3    7/30/1977
# 4    12/1/1988
# 5   11/11/1980
# ...

# %%
df.to_csv(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/Exports/parks_and_recreation.csv',
           index = False)

# %%
df.to_excel(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/Exports/parks_and_recreation.xlsx',
           index = False, sheet_name = 'Employees')

# %%
df.to_json(r'/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/Exports/parks_and_recreation.json'
           )
