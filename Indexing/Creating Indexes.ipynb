# %% [markdown]
# ### Creating an Index

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/WorldContinents.csv',
                    encoding = 'ISO-8859-1')

df
# Out:
#     continent       sub_region            country code_3     Unnamed: 4
# 0        Asia    Southern Asia        Afghanistan    AFG     6,900,000
# 1      Europe  Northern Europe      Åland Islands    ALA     5,500,000
# 2      Europe  Southern Europe            Albania    ALB     3,300,000
# 3      Africa  Northern Africa            Algeria    DZA     9,500,000
# 4     Oceania        Polynesia     American Samoa    ASM        55,000
# ..        ...              ...                ...    ...            ...
# 235   Oceania        Polynesia  Wallis and Futuna    WLF    15,900,000
# 236    Africa  Northern Africa     Western Sahara    ESH       597,000
# 237      Asia     Western Asia              Yemen    YEM     5,500,000
# 238    Africa   Eastern Africa             Zambia    ZMB   213,000,000
# 239    Africa   Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
df_World = pd.read_csv('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/WorldContinents.csv',
                    encoding = 'ISO-8859-1', index_col = 'country') 
                    #index_col = 'country' makes this column an index

df_World
# Out:
#                   continent       sub_region code_3     Unnamed: 4
# country
# Afghanistan            Asia    Southern Asia    AFG     6,900,000
# Åland Islands        Europe  Northern Europe    ALA     5,500,000
# Albania              Europe  Southern Europe    ALB     3,300,000
# Algeria              Africa  Northern Africa    DZA     9,500,000
# American Samoa      Oceania        Polynesia    ASM        55,000
# ...                     ...              ...    ...            ...
# Wallis and Futuna   Oceania        Polynesia    WLF    15,900,000
# Western Sahara       Africa  Northern Africa    ESH       597,000
# Yemen                  Asia     Western Asia    YEM     5,500,000
# Zambia               Africa   Eastern Africa    ZMB   213,000,000
# Zimbabwe             Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 4 columns]

# %%
df_Continent = pd.read_csv('/Users/georgiosskourlis/Documents/Analyst Builder/Pandas for Data Analysis/WorldContinents.csv',
                    encoding = 'ISO-8859-1', index_col = 'continent') 
                    #index_col = 'continent' makes this column an index

df_Continent
# Out:
#                 sub_region            country code_3     Unnamed: 4
# continent
# Asia         Southern Asia        Afghanistan    AFG     6,900,000
# Europe     Northern Europe      Åland Islands    ALA     5,500,000
# Europe     Southern Europe            Albania    ALB     3,300,000
# Africa     Northern Africa            Algeria    DZA     9,500,000
# Oceania          Polynesia     American Samoa    ASM        55,000
# ...                    ...                ...    ...            ...
# Oceania          Polynesia  Wallis and Futuna    WLF    15,900,000
# Africa     Northern Africa     Western Sahara    ESH       597,000
# Asia          Western Asia              Yemen    YEM     5,500,000
# Africa      Eastern Africa             Zambia    ZMB   213,000,000
# Africa      Eastern Africa           Zimbabwe    ZWE    19,100,000
#
# [240 rows x 4 columns]

# %%
df_World.loc['Albania']
# Out:
# continent              Europe
# sub_region    Southern Europe
# code_3                    ALB
# Unnamed: 4         3,300,000
# Name: Albania, dtype: object

# %%
df_Continent.loc['Asia']
# Out:
#                    sub_region                                  country code_3  \
# continent
# Asia            Southern Asia                              Afghanistan    AFG
# Asia             Western Asia                                  Armenia    ARM
# Asia             Western Asia                               Azerbaijan    AZE
# Asia             Western Asia                                  Bahrain    BHR
# Asia            Southern Asia                               Bangladesh    BGD
# Asia            Southern Asia                                   Bhutan    BTN
# Asia       South-Eastern Asia                        Brunei Darussalam    BRN
# Asia       South-Eastern Asia                                 Cambodia    KHM
# Asia             Eastern Asia                                    China    CHN
# Asia             Western Asia                                   Cyprus    CYP
# Asia             Western Asia                                  Georgia    GEO
# ...

# %%
# We can set the index like this as well (for the first dataframe) but this means that we lost the orginial index

df.set_index('country', inplace = True)

df
# Out:
#                    index continent       sub_region code_3     Unnamed: 4
# country
# Afghanistan            0      Asia    Southern Asia    AFG     6,900,000
# Åland Islands          1    Europe  Northern Europe    ALA     5,500,000
# Albania                2    Europe  Southern Europe    ALB     3,300,000
# Algeria                3    Africa  Northern Africa    DZA     9,500,000
# American Samoa         4   Oceania        Polynesia    ASM        55,000
# ...                  ...       ...              ...    ...            ...
# Wallis and Futuna    235   Oceania        Polynesia    WLF    15,900,000
# Western Sahara       236    Africa  Northern Africa    ESH       597,000
# Yemen                237      Asia     Western Asia    YEM     5,500,000
# Zambia               238    Africa   Eastern Africa    ZMB   213,000,000
# Zimbabwe             239    Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
# With --> df.reset_index you can reset your index as it where at the start

df.reset_index(inplace = True)
df
# Out:
#                country  index continent       sub_region code_3     Unnamed: 4
# 0          Afghanistan      0      Asia    Southern Asia    AFG     6,900,000
# 1        Åland Islands      1    Europe  Northern Europe    ALA     5,500,000
# 2              Albania      2    Europe  Southern Europe    ALB     3,300,000
# 3              Algeria      3    Africa  Northern Africa    DZA     9,500,000
# 4       American Samoa      4   Oceania        Polynesia    ASM        55,000
# ..                 ...    ...       ...              ...    ...            ...
# 235  Wallis and Futuna    235   Oceania        Polynesia    WLF    15,900,000
# 236     Western Sahara    236    Africa  Northern Africa    ESH       597,000
# 237              Yemen    237      Asia     Western Asia    YEM     5,500,000
# 238             Zambia    238    Africa   Eastern Africa    ZMB   213,000,000
# 239           Zimbabwe    239    Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 6 columns]

# %% [markdown]
# ### Multi-Level Indexing

# %%
df.drop('index', axis = 1)
# Out:
#                country continent       sub_region code_3     Unnamed: 4
# 0          Afghanistan      Asia    Southern Asia    AFG     6,900,000
# 1        Åland Islands    Europe  Northern Europe    ALA     5,500,000
# 2              Albania    Europe  Southern Europe    ALB     3,300,000
# 3              Algeria    Africa  Northern Africa    DZA     9,500,000
# 4       American Samoa   Oceania        Polynesia    ASM        55,000
# ..                 ...       ...              ...    ...            ...
# 235  Wallis and Futuna   Oceania        Polynesia    WLF    15,900,000
# 236     Western Sahara    Africa  Northern Africa    ESH       597,000
# 237              Yemen      Asia     Western Asia    YEM     5,500,000
# 238             Zambia    Africa   Eastern Africa    ZMB   213,000,000
# 239           Zimbabwe    Africa   Eastern Africa    ZWE    19,100,000
#
# [240 rows x 5 columns]

# %%
#Create hierarchies

df2 = df.set_index(['continent','sub_region']).sort_values(by = (['continent','sub_region']), ascending = [False,True])
df2
# Out:
#                                                                           country  \
# continent sub_region
# Oceania   Australia and New Zealand                                     Australia
#           Australia and New Zealand                                   New Zealand
#           Australia and New Zealand                                Norfolk Island
#           Melanesia                                                          Fiji
#           Melanesia                                                 New Caledonia
# ...                                                                           ...
# Africa    Western Africa                                                  Nigeria
#           Western Africa             Saint Helena, Ascension and Tristan da Cunha
#           Western Africa                                                  Senegal
#           Western Africa                                             Sierra Leone
# ...

# %%
df2.loc['Oceania']
# Out:
#                                                     country  index code_3  \
# sub_region
# Australia and New Zealand                         Australia     12    AUS
# Australia and New Zealand                       New Zealand    151    NZL
# Australia and New Zealand                    Norfolk Island    156    NFK
# Melanesia                                              Fiji     68    FJI
# Melanesia                                     New Caledonia    150    NCL
# Melanesia                                  Papua New Guinea    164    PNG
# Melanesia                                   Solomon Islands    196    SLB
# Melanesia                                           Vanuatu    230    VUT
# Micronesia                                             Guam     83    GUM
# Micronesia                                         Kiribati    109    KIR
# Micronesia                                 Marshall Islands    131    MHL
# ...
